# %% [markdown]
# # Q 1

# %% [markdown]
# Number of clock cycles = 163 - 21 = 142

# %% [markdown]
# # Q 2

# %% [markdown]
# Number of bubbles = 57 - 9 = 48

# %% [markdown]
# # Q 3

# %% [markdown]
# The break (BLT and BEQ) and jump (JAL and JALR) instructions

# %% [markdown]
# # Q 4

# %% [markdown]
# Use less branches and jumps, potentially by finding a method other than a loop to calculate n.
